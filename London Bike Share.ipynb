# %%
import pandas as pd

# %%
bikeshares_data = pd.read_csv("london_merged.csv")

# %%
bikeshares_data
# Out:
#           timestamp   cnt   t1   t2    hum  wind_speed  weather_code  \
# 0       1/4/15 0:00   182  3.0  2.0   93.0         6.0             3
# 1       1/4/15 1:00   138  3.0  2.5   93.0         5.0             1
# 2       1/4/15 2:00   134  2.5  2.5   96.5         0.0             1
# 3       1/4/15 3:00    72  2.0  2.0  100.0         0.0             1
# 4       1/4/15 4:00    47  2.0  0.0   93.0         6.5             1
# ...             ...   ...  ...  ...    ...         ...           ...
# 17409  1/3/17 19:00  1042  5.0  1.0   81.0        19.0             3
# 17410  1/3/17 20:00   541  5.0  1.0   81.0        21.0             4
# 17411  1/3/17 21:00   337  5.5  1.5   78.5        24.0             4
# 17412  1/3/17 22:00   224  5.5  1.5   76.0        23.0             4
# 17413  1/3/17 23:00   139  5.0  1.0   76.0        22.0             2
#
#        is_holiday  is_weekend  season
# 0               0           1       3
# 1               0           1       3
# ...

# %%
bikeshares_data.isnull().values.any()
# Out:
# False

# %%
bikeshares_data.isnull().sum()
# Out:
# timestamp       0
# cnt             0
# t1              0
# t2              0
# hum             0
# wind_speed      0
# weather_code    0
# is_holiday      0
# is_weekend      0
# season          0
# dtype: int64

# %%
bsd = bikeshares_data.rename(columns = {'cnt':'bike_count', 't1':'real_temp', 't2': 'feels_like_temp','hum':'humidity'})

# %%
bsd.max(axis = 0)
# Out:
# timestamp          9/9/16 9:00
# bike_count                7860
# real_temp                 34.0
# feels_like_temp           34.0
# humidity                 100.0
# wind_speed                56.5
# weather_code                26
# is_holiday                   1
# is_weekend                   1
# season                       3
# dtype: object

# %%
bsd.min(axis =0)
# Out:
# timestamp          1/1/16 0:00
# bike_count                   0
# real_temp                 -1.5
# feels_like_temp           -6.0
# humidity                  20.5
# wind_speed                 0.0
# weather_code                 1
# is_holiday                   0
# is_weekend                   0
# season                       0
# dtype: object

# %%
bsd.describe()
# Out:
#          bike_count     real_temp  feels_like_temp      humidity  \
# count  17414.000000  17414.000000     17414.000000  17414.000000
# mean    1143.101642     12.468091        11.520836     72.324954
# std     1085.108068      5.571818         6.615145     14.313186
# min        0.000000     -1.500000        -6.000000     20.500000
# 25%      257.000000      8.000000         6.000000     63.000000
# 50%      844.000000     12.500000        12.500000     74.500000
# 75%     1671.750000     16.000000        16.000000     83.000000
# max     7860.000000     34.000000        34.000000    100.000000
#
#          wind_speed  weather_code    is_holiday    is_weekend        season
# count  17414.000000  17414.000000  17414.000000  17414.000000  17414.000000
# mean      15.913063      2.722752      0.022051      0.285403      1.492075
# std        7.894570      2.341163      0.146854      0.451619      1.118911
# min        0.000000      1.000000      0.000000      0.000000      0.000000
# ...

# %%
bsd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17414 entries, 0 to 17413
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   timestamp        17414 non-null  object
#  1   bike_count       17414 non-null  int64
#  2   real_temp        17414 non-null  float64
#  3   feels_like_temp  17414 non-null  float64
#  4   humidity         17414 non-null  float64
#  5   wind_speed       17414 non-null  float64
#  6   weather_code     17414 non-null  int64
#  7   is_holiday       17414 non-null  int64
#  8   is_weekend       17414 non-null  int64
#  9   season           17414 non-null  int64
# dtypes: float64(4), int64(5), object(1)
# memory usage: 1.3+ MB

# %%
average = bsd['bike_count'].mean()

# %%
print(average)
# Out:
# 1143.1016423567244

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.relplot(x = "t1", y = "cnt", data = bikeshares_data)

# %%
sns.boxplot(x = "weather_code", y = "cnt", data = bikeshares_data)
# Out:
# <AxesSubplot:xlabel='weather_code', ylabel='cnt'>

# %%
sns.boxplot(x = "weather_code", y = "cnt", data = bikeshares_data)
# Out:
# <AxesSubplot:xlabel='weather_code', ylabel='cnt'>

# %%
sns.boxplot(x = "season", y = "bike_count", data = bsd)
# Out:
# <AxesSubplot:xlabel='season', ylabel='bike_count'>

# %%
sns.scatterplot(x = "weather_code", y = "cnt", data = bikeshares_data)
# Out:
# <AxesSubplot:xlabel='weather_code', ylabel='cnt'>

# %%
bsd.head()
# Out:
#      timestamp  bike_count  real_temp  feels_like_temp  humidity  wind_speed  \
# 0  1/4/15 0:00         182        3.0              2.0      93.0         6.0
# 1  1/4/15 1:00         138        3.0              2.5      93.0         5.0
# 2  1/4/15 2:00         134        2.5              2.5      96.5         0.0
# 3  1/4/15 3:00          72        2.0              2.0     100.0         0.0
# 4  1/4/15 4:00          47        2.0              0.0      93.0         6.5
#
#    weather_code  is_holiday  is_weekend  season
# 0             3           0           1       3
# 1             1           0           1       3
# 2             1           0           1       3
# 3             1           0           1       3
# 4             1           0           1       3

# %%
bsd.dtypes
# Out:
# timestamp           object
# bike_count           int64
# real_temp          float64
# feels_like_temp    float64
# humidity           float64
# wind_speed         float64
# weather_code         int64
# is_holiday           int64
# is_weekend           int64
# season               int64
# dtype: object

# %%
bsd['timestamp'] = bsd['timestamp'].astype('datetime64[ns]')

# %%
bsd.dtypes
# Out:
# timestamp          datetime64[ns]
# bike_count                  int64
# real_temp                 float64
# feels_like_temp           float64
# humidity                  float64
# wind_speed                float64
# weather_code                int64
# is_holiday                  int64
# is_weekend                  int64
# season                      int64
# dtype: object

# %%
bsd['date'] = bsd['timestamp'].dt.date

# %%
bsd.groupby('date').mean()
# Out:
#             bike_count  real_temp  feels_like_temp   humidity  wind_speed  \
# date
# 2015-01-04  384.750000   2.479167         0.645833  94.270833    7.500000
# 2015-01-05  848.833333   8.041667         6.708333  80.312500    8.854167
# 2015-01-06  858.875000   7.854167         5.333333  78.895833   16.000000
# 2015-01-07  915.826087   7.456522         4.500000  78.108696   19.760870
# 2015-01-08  650.041667   9.750000         7.791667  79.312500   20.479167
# ...                ...        ...              ...        ...         ...
# 2016-12-30  481.916667   3.270833         1.062500  98.687500    9.000000
# 2016-12-31  476.000000   7.437500         5.041667  90.958333   13.312500
# 2017-01-01  267.541667   7.000000         4.437500  88.437500   14.125000
# 2017-01-02  492.625000   3.729167         0.937500  83.145833   11.166667
# 2017-01-03  809.833333   3.395833        -0.625000  81.395833   18.937500
#
#             weather_code  is_holiday  is_weekend  season
# date
# ...

# %%
sns.relplot(x = "cnt", y = "weather_code", data = bikeshares_data)

# %%
sns.regplot(x="bike_count", y="real_temp", data=bsd);

# %%
bsd.head(50)
# Out:
#              timestamp  bike_count  real_temp  feels_like_temp  humidity  \
# 0  2015-01-04 00:00:00         182        3.0              2.0      93.0
# 1  2015-01-04 01:00:00         138        3.0              2.5      93.0
# 2  2015-01-04 02:00:00         134        2.5              2.5      96.5
# 3  2015-01-04 03:00:00          72        2.0              2.0     100.0
# 4  2015-01-04 04:00:00          47        2.0              0.0      93.0
# 5  2015-01-04 05:00:00          46        2.0              2.0      93.0
# 6  2015-01-04 06:00:00          51        1.0             -1.0     100.0
# 7  2015-01-04 07:00:00          75        1.0             -1.0     100.0
# 8  2015-01-04 08:00:00         131        1.5             -1.0      96.5
# 9  2015-01-04 09:00:00         301        2.0             -0.5     100.0
# 10 2015-01-04 10:00:00         528        3.0             -0.5      93.0
# 11 2015-01-04 11:00:00         727        2.0             -1.5     100.0
# ...

# %%
bsd1 = pd.read_csv("london_merged.csv")

# %%
bsd1.head(24)
# Out:
#        timestamp   cnt   t1   t2    hum  wind_speed  weather_code  is_holiday  \
# 0    1/4/15 0:00   182  3.0  2.0   93.0         6.0             3           0
# 1    1/4/15 1:00   138  3.0  2.5   93.0         5.0             1           0
# 2    1/4/15 2:00   134  2.5  2.5   96.5         0.0             1           0
# 3    1/4/15 3:00    72  2.0  2.0  100.0         0.0             1           0
# 4    1/4/15 4:00    47  2.0  0.0   93.0         6.5             1           0
# 5    1/4/15 5:00    46  2.0  2.0   93.0         4.0             1           0
# 6    1/4/15 6:00    51  1.0 -1.0  100.0         7.0             4           0
# 7    1/4/15 7:00    75  1.0 -1.0  100.0         7.0             4           0
# 8    1/4/15 8:00   131  1.5 -1.0   96.5         8.0             4           0
# 9    1/4/15 9:00   301  2.0 -0.5  100.0         9.0             3           0
# 10  1/4/15 10:00   528  3.0 -0.5   93.0        12.0             3           0
# ...

# %%
bsd1['weather_code']
# Out:
# 0        3
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 17409    3
# 17410    4
# 17411    4
# 17412    4
# 17413    2
# Name: weather_code, Length: 17414, dtype: int64

# %%
weather_code = bsd1.loc[2:8, ['weather_code']]

# %%
display(weather_code)
# Out:
#    weather_code
# 2             1
# 3             1
# 4             1
# 5             1
# 6             4
# 7             4
# 8             4

# %%
weather_code.head()
# Out:
#    weather_code
# 2             1
# 3             1
# 4             1
# 5             1
# 6             4

# %%
bsd1.iloc[0]
# Out:
# timestamp       1/4/15 0:00
# cnt                     182
# t1                      3.0
# t2                      2.0
# hum                    93.0
# wind_speed              6.0
# weather_code              3
# is_holiday                0
# is_weekend                1
# season                    3
# Name: 0, dtype: object

# %%
bsd1.iloc[0:12]
# Out:
#        timestamp  cnt   t1   t2    hum  wind_speed  weather_code  is_holiday  \
# 0    1/4/15 0:00  182  3.0  2.0   93.0         6.0             3           0
# 1    1/4/15 1:00  138  3.0  2.5   93.0         5.0             1           0
# 2    1/4/15 2:00  134  2.5  2.5   96.5         0.0             1           0
# 3    1/4/15 3:00   72  2.0  2.0  100.0         0.0             1           0
# 4    1/4/15 4:00   47  2.0  0.0   93.0         6.5             1           0
# 5    1/4/15 5:00   46  2.0  2.0   93.0         4.0             1           0
# 6    1/4/15 6:00   51  1.0 -1.0  100.0         7.0             4           0
# 7    1/4/15 7:00   75  1.0 -1.0  100.0         7.0             4           0
# 8    1/4/15 8:00  131  1.5 -1.0   96.5         8.0             4           0
# 9    1/4/15 9:00  301  2.0 -0.5  100.0         9.0             3           0
# 10  1/4/15 10:00  528  3.0 -0.5   93.0        12.0             3           0
# ...

# %%
bsd1.iloc[0:23, 6]
# Out:
# 0     3
# 1     1
# 2     1
# 3     1
# 4     1
# 5     1
# 6     4
# 7     4
# 8     4
# 9     3
# 10    3
# 11    3
# 12    4
# 13    3
# 14    3
# 15    3
# 16    3
# 17    3
# 18    3
# 19    3
# 20    3
# 21    4
# 22    4
# Name: weather_code, dtype: int64

# %%
uniquenume = bsd1.iloc[0:23, 6]

# %%
print(uniquenume.nunique())
# Out:
# 3

# %%
bsd1.iloc[0:23, 6].mode()
# Out:
# 0    3
# Name: weather_code, dtype: int64

# %%
bsd1['date'] = bsd['timestamp'].dt.date

# %%
bsd1.head()
# Out:
#      timestamp  cnt   t1   t2    hum  wind_speed  weather_code  is_holiday  \
# 0  1/4/15 0:00  182  3.0  2.0   93.0         6.0             3           0
# 1  1/4/15 1:00  138  3.0  2.5   93.0         5.0             1           0
# 2  1/4/15 2:00  134  2.5  2.5   96.5         0.0             1           0
# 3  1/4/15 3:00   72  2.0  2.0  100.0         0.0             1           0
# 4  1/4/15 4:00   47  2.0  0.0   93.0         6.5             1           0
#
#    is_weekend  season        date
# 0           1       3  2015-01-04
# 1           1       3  2015-01-04
# 2           1       3  2015-01-04
# 3           1       3  2015-01-04
# 4           1       3  2015-01-04

# %%
bsd2 = bsd1.groupby('date').aggregate({
    'cnt': 'max',
    't1':'mean',
    't2': 'mean',
    'hum': 'mean',
    'wind_speed': 'mean',
     'weather_code':lambda x:x.value_counts().index[0],
    'is_holiday': 'mean',
    'is_weekend': 'mean',
    
    'season': 'mean'})

# %%
bsd2.head(50)
# Out:
#              cnt         t1         t2        hum  wind_speed  weather_code  \
# date
# 2015-01-04  1039   2.479167   0.645833  94.270833    7.500000             3
# 2015-01-05  3161   8.041667   6.708333  80.312500    8.854167             3
# 2015-01-06  3534   7.854167   5.333333  78.895833   16.000000             1
# 2015-01-07  3618   7.456522   4.500000  78.108696   19.760870             2
# 2015-01-08  2351   9.750000   7.791667  79.312500   20.479167             7
# 2015-01-09  3505  12.729167  12.333333  74.854167   32.916667             3
# 2015-01-10  1436  10.479167   8.708333  66.125000   34.312500             3
# 2015-01-11  1813   6.645833   2.458333  67.583333   26.562500             1
# 2015-01-12  3418  11.125000   9.750000  76.583333   28.187500             7
# 2015-01-13  3960   8.604167   6.083333  75.812500   21.208333             7
# 2015-01-14  3904   6.500000   2.479167  67.125000   25.750000             2
# ...

# %%
sns.boxplot(x = "season", y = "cnt", data = bsd2)
# Out:
# <AxesSubplot:xlabel='season', ylabel='cnt'>

# %%
sns.boxplot(x = "weather_code", y = "cnt", data = bsd2)
# Out:
# <AxesSubplot:xlabel='weather_code', ylabel='cnt'>

# %%
bsd2.to_csv('/Users/rajusubba/Documents/Data Science Project/bike_share_group.csv')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Input In [46], in <cell line: 1>()
# ----> 1 bsd2.to_csv('/Users/rajusubba/Documents/Data Science Project/bike_share_group.csv')
#
# File /opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py:3551, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3540 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3542 formatter = DataFrameFormatter(
#    3543     frame=df,
#    3544     header=header,
#    (...)
#    3548     decimal=decimal,
#    3549 )
# -> 3551 return DataFrameRenderer(formatter).to_csv(
#    3552     path_or_buf,
#    3553     line_terminator=line_terminator,
#    3554     sep=sep,
# ...

# %%
import os
os.getcwd()
# Out:
# '/Users/rajusubba/Documents - Raju’s MacBook Pro - 1/Data Science Project'

# %%
bsd2.head(50)
# Out:
#              cnt         t1         t2        hum  wind_speed  weather_code  \
# date
# 2015-01-04  1039   2.479167   0.645833  94.270833    7.500000             3
# 2015-01-05  3161   8.041667   6.708333  80.312500    8.854167             3
# 2015-01-06  3534   7.854167   5.333333  78.895833   16.000000             1
# 2015-01-07  3618   7.456522   4.500000  78.108696   19.760870             2
# 2015-01-08  2351   9.750000   7.791667  79.312500   20.479167             7
# 2015-01-09  3505  12.729167  12.333333  74.854167   32.916667             3
# 2015-01-10  1436  10.479167   8.708333  66.125000   34.312500             3
# 2015-01-11  1813   6.645833   2.458333  67.583333   26.562500             1
# 2015-01-12  3418  11.125000   9.750000  76.583333   28.187500             7
# 2015-01-13  3960   8.604167   6.083333  75.812500   21.208333             7
# 2015-01-14  3904   6.500000   2.479167  67.125000   25.750000             2
# ...

# %%
list(bsd2.columns)
# Out:
# ['cnt',
#  't1',
#  't2',
#  'hum',
#  'wind_speed',
#  'weather_code',
#  'is_holiday',
#  'is_weekend',
#  'season']

# %%
sns.regplot(x="cnt", y="t1", data=bsd2);

# %%
sns.scatterplot(x="cnt", y="t1", data=bsd2);

# %%
sns.scatterplot(x="t1", y="cnt", data=bsd2);

# %%
x = bsd2.drop(columns = 'cnt')

# %%
x
# Out:
#                   t1        t2        hum  wind_speed  weather_code  \
# date
# 2015-01-04  2.479167  0.645833  94.270833    7.500000             3
# 2015-01-05  8.041667  6.708333  80.312500    8.854167             3
# 2015-01-06  7.854167  5.333333  78.895833   16.000000             1
# 2015-01-07  7.456522  4.500000  78.108696   19.760870             2
# 2015-01-08  9.750000  7.791667  79.312500   20.479167             7
# ...              ...       ...        ...         ...           ...
# 2016-12-30  3.270833  1.062500  98.687500    9.000000             4
# 2016-12-31  7.437500  5.041667  90.958333   13.312500             4
# 2017-01-01  7.000000  4.437500  88.437500   14.125000             7
# 2017-01-02  3.729167  0.937500  83.145833   11.166667             1
# 2017-01-03  3.395833 -0.625000  81.395833   18.937500             1
#
#             is_holiday  is_weekend  season
# date
# 2015-01-04         0.0         1.0     3.0
# 2015-01-05         0.0         0.0     3.0
# ...

# %%
y = bsd2['cnt']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state = 0)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

# %%
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
c = lr.intercept_
c
# Out:
# 6048.708151025713

# %%
m = lr.coef_
m
# Out:
# array([  -41.43467247,    87.38867946,   -27.36699253,   -24.91451773,
#          -43.11784805, -1754.88588337, -1763.38204394,   -13.97533517])

# %%
y_prep_train = lr.predict(x_train)

# %%
y_prep_train
# Out:
# array([4284.24930562, 2616.92423012, 3698.34231483, 2348.77469528,
#        4139.22394323, 4316.07291244, 4048.61625395, 1821.429539  ,
#        4148.72879432, 4644.801298  , 1407.84468241, 3453.98056281,
#        4715.41258294, 4089.52021876, 2200.04940664, 3851.21329016,
#        4010.04017677, 3866.05133853, 3772.23920527, 3616.54494308,
#        3462.50264753, 4013.36127068, 3766.33543496, 3509.78305683,
#        4978.04511818, 2418.64638731, 3502.95953322, 3488.99768146,
#        2824.34398985, 2878.71247689, 1776.3336984 , 1590.7639902 ,
#        3273.07091595, 1523.14233454, 3386.65047957, 3531.38674086,
#        3608.56161564, 2200.55257756, 3529.5584148 , 3726.02836469,
#        3464.93191495, 1970.31555843, 4063.08395523, 3072.16676668,
#        3938.25229972, 4362.9932395 , 1851.91921259, 3967.81164268,
#        4432.53525765, 1450.17249483, 4047.91378771, 4085.2924652 ,
#        1764.44009688, 4674.29139799, 4655.022564  , 2803.40716733,
# ...

# %%
import matplotlib.pyplot as plt
plt.scatter(y_train, y_prep_train)
plt.xlabel("Actual_cnt")
plt.ylabel("Predicted cnt")
plt.show()

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_train, y_prep_train)
# Out:
# 0.7836116930842842

# %%
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
lr.fit(x_test, y_test)
# Out:
# LinearRegression()

# %%
c = lr.intercept_
c
# Out:
# 5056.629615208383

# %%
m = lr.coef_

# %%
m
# Out:
# array([    9.66240702,    60.22952975,   -17.02242435,   -26.9191503 ,
#          -53.63339606, -2123.60370572, -1573.33854739,   -42.76569736])

# %%
y_prep_test = lr.predict(x_test)

# %%
plt.scatter(y_test, y_prep_test)
plt.xlabel("Actual_cnt")
plt.ylabel("Predicted cnt")
plt.show()

# %%
r2_score(y_test, y_prep_test)
# Out:
# 0.7311733393903317
